# %%
#Install necessary libraries
# !pip install openneuro-py mne
# Out:
# ...
#   Obtaining dependency information for openneuro-py from https://files.pythonhosted.org/packages/9f/4e/380ed6fe4b1001c39fff409032877c7bd8ae5745574e03ca273f7f37b2ad/openneuro_py-2024.2.0-py3-none-any.whl.metadata
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 898.0 kB/s eta 0:00:00a 0:00:01
# ...
#   Obtaining dependency information for mne from https://files.pythonhosted.org/packages/80/8e/e3e7de62143236712c359db50c6bd6486557b1c5efb7d45682b8efc0a6a6/mne-1.9.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for aiofiles from https://files.pythonhosted.org/packages/a5/45/30bb92d442636f570cb5651bc661f52b610e2eec3f891a5dc3a4c3667db0/aiofiles-24.1.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for httpx>=0.15 from https://files.pythonhosted.org/packages/2a/39/e50c7c3a983047577ee07d2a9e53faf5a69493943ec3f6a384bdc792deb2/httpx-0.28.1-py3-none-any.whl.metadata
# ...

# %%
from openneuro import download

dataset = "ds005873"

# Carpeta destino
target_dir = "/home/ferna96/Documents/personal/MaestriaFM/GPU/una_challenge_analysis/una-challenge-analysis/data/raw/data/ds005873"

# Generar patrones de inclusión para los primeros 10 sujetos
include_patterns = [f"sub-{i:03}/ses-01/eeg/**" for i in range(1, 11)]

# Descargar usando todos los patrones
download(
    dataset=dataset,
    target_dir=target_dir,
    include=include_patterns
)
# Out:
# 👋 Hello! This is openneuro-py 2024.2.0. Great to see you! 🤗
#
#    👉 Please report problems 🤯 and bugs 🪲 at
#       https://github.com/hoechenberger/openneuro-py/issues
#
# 🌍 Preparing to download ds005873 …
# 📁 Traversing directories for ds005873 : 952 entities [01:56,  8.17 entities/s]
# 📥 Retrieving up to 320 files (5 concurrent downloads).
# ✅ Finished downloading ds005873.
#
# 🧠 Please enjoy your brains.
# 🔄 Request timed out while downloading /home/ferna96/Documents/personal/MaestriaFM/GPU/una_challenge_analysis/una-challenge-analysis/data/raw/data/ds005873/sub-002/ses-01/eeg/sub-002_ses-01_task-szMonitoring_run-09_events.tsv, retrying in 0.5 sec …
# 🔄 Request timed out while downloading /home/ferna96/Documents/personal/MaestriaFM/GPU/una_challenge_analysis/una-challenge-analysis/data/raw/data/ds005873/sub-002/ses-01/eeg/sub-002_ses-01_task-szMonitoring_run-10_eeg.edf, retrying in 0.5 sec …
# ...

# %%
import mne

eeg_file_path = "/home/ferna96/Documents/personal/MaestriaFM/GPU/una_challenge_analysis/una-challenge-analysis/data/raw/ds005873/sub-001/ses-01/eeg/sub-001_ses-01_task-szMonitoring_run-08_eeg.edf"

# Load the EDF file
raw = mne.io.read_raw_edf(eeg_file_path, preload=True)

# Visualize the raw data
raw.plot()
# Out:
# Extracting EDF parameters from /home/ferna96/Documents/personal/MaestriaFM/GPU/una_challenge_analysis/una-challenge-analysis/data/raw/ds005873/sub-001/ses-01/eeg/sub-001_ses-01_task-szMonitoring_run-08_eeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 13178367  =      0.000 ... 51477.996 secs...
# Using matplotlib as 2D backend.
# <MNEBrowseFigure size 1920x1052 with 4 Axes>
# <MNEBrowseFigure size 1920x1052 with 4 Axes>
